# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline

# %%
# This data is from http://www.datasciencemadesimple.com/python-pandas-tutorial/.

d = { 'Name':['Alisa','Bobby','Cathrine','Alisa','Bobby','Cathrine', \
              'Alisa','Bobby','Cathrine','Alisa','Bobby','Cathrine'], \
      'Exam':['Semester 1','Semester 1','Semester 1','Semester 1','Semester 1','Semester 1', \
             'Semester 2','Semester 2','Semester 2','Semester 2','Semester 2','Semester 2'], \
      'Subject':['Mathematics','Mathematics','Mathematics','Science','Science','Science', \
                        'Mathematics','Mathematics','Mathematics','Science','Science','Science'], \
      'Score':[62,47,55,74,31,77,85,63,42,67,89,81]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#         Name        Exam      Subject  Score
# 0      Alisa  Semester 1  Mathematics     62
# 1      Bobby  Semester 1  Mathematics     47
# 2   Cathrine  Semester 1  Mathematics     55
# 3      Alisa  Semester 1      Science     74
# 4      Bobby  Semester 1      Science     31
# 5   Cathrine  Semester 1      Science     77
# 6      Alisa  Semester 2  Mathematics     85
# 7      Bobby  Semester 2  Mathematics     63
# 8   Cathrine  Semester 2  Mathematics     42
# 9      Alisa  Semester 2      Science     67
# 10     Bobby  Semester 2      Science     89
# 11  Cathrine  Semester 2      Science     81

# %%
df.to_csv('d.csv')

# %%
# !cat d.csv
# Out:
# ,Name,Exam,Subject,Score
# 0,Alisa,Semester 1,Mathematics,62
# 1,Bobby,Semester 1,Mathematics,47
# 2,Cathrine,Semester 1,Mathematics,55
# 3,Alisa,Semester 1,Science,74
# 4,Bobby,Semester 1,Science,31
# 5,Cathrine,Semester 1,Science,77
# 6,Alisa,Semester 2,Mathematics,85
# 7,Bobby,Semester 2,Mathematics,63
# 8,Cathrine,Semester 2,Mathematics,42
# 9,Alisa,Semester 2,Science,67
# 10,Bobby,Semester 2,Science,89
# 11,Cathrine,Semester 2,Science,81

# %%
df2 = pd.read_csv('d.csv')

# %%
df2
# Out:
#     Unnamed: 0      Name        Exam      Subject  Score
# 0            0     Alisa  Semester 1  Mathematics     62
# 1            1     Bobby  Semester 1  Mathematics     47
# 2            2  Cathrine  Semester 1  Mathematics     55
# 3            3     Alisa  Semester 1      Science     74
# 4            4     Bobby  Semester 1      Science     31
# 5            5  Cathrine  Semester 1      Science     77
# 6            6     Alisa  Semester 2  Mathematics     85
# 7            7     Bobby  Semester 2  Mathematics     63
# 8            8  Cathrine  Semester 2  Mathematics     42
# 9            9     Alisa  Semester 2      Science     67
# 10          10     Bobby  Semester 2      Science     89
# 11          11  Cathrine  Semester 2      Science     81

# %%
df2 = df2.drop('Unnamed: 0', axis=1)

# %%
df2
# Out:
#         Name        Exam      Subject  Score
# 0      Alisa  Semester 1  Mathematics     62
# 1      Bobby  Semester 1  Mathematics     47
# 2   Cathrine  Semester 1  Mathematics     55
# 3      Alisa  Semester 1      Science     74
# 4      Bobby  Semester 1      Science     31
# 5   Cathrine  Semester 1      Science     77
# 6      Alisa  Semester 2  Mathematics     85
# 7      Bobby  Semester 2  Mathematics     63
# 8   Cathrine  Semester 2  Mathematics     42
# 9      Alisa  Semester 2      Science     67
# 10     Bobby  Semester 2      Science     89
# 11  Cathrine  Semester 2      Science     81

# %%
df.shape
# Out:
# (12, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
# Name       12 non-null object
# Exam       12 non-null object
# Subject    12 non-null object
# Score      12 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 512.0+ bytes

# %%
df.head()
# Out:
#        Name        Exam      Subject  Score
# 0     Alisa  Semester 1  Mathematics     62
# 1     Bobby  Semester 1  Mathematics     47
# 2  Cathrine  Semester 1  Mathematics     55
# 3     Alisa  Semester 1      Science     74
# 4     Bobby  Semester 1      Science     31

# %%
df.tail()
# Out:
#         Name        Exam      Subject  Score
# 7      Bobby  Semester 2  Mathematics     63
# 8   Cathrine  Semester 2  Mathematics     42
# 9      Alisa  Semester 2      Science     67
# 10     Bobby  Semester 2      Science     89
# 11  Cathrine  Semester 2      Science     81

# %%
df.iloc[2, 3]
# Out:
# 55

# %%
df
# Out:
#         Name        Exam      Subject  Score
# 0      Alisa  Semester 1  Mathematics     62
# 1      Bobby  Semester 1  Mathematics     47
# 2   Cathrine  Semester 1  Mathematics     55
# 3      Alisa  Semester 1      Science     74
# 4      Bobby  Semester 1      Science     31
# 5   Cathrine  Semester 1      Science     77
# 6      Alisa  Semester 2  Mathematics     85
# 7      Bobby  Semester 2  Mathematics     63
# 8   Cathrine  Semester 2  Mathematics     42
# 9      Alisa  Semester 2      Science     67
# 10     Bobby  Semester 2      Science     89
# 11  Cathrine  Semester 2      Science     81

# %%
df.iloc[:2, :3]
# Out:
#     Name        Exam      Subject
# 0  Alisa  Semester 1  Mathematics
# 1  Bobby  Semester 1  Mathematics

# %%
df.loc[2, 'Name']
# Out:
# 'Cathrine'

# %%
df['Name'].unique()
# Out:
# array(['Alisa', 'Bobby', 'Cathrine'], dtype=object)

# %%
df[df['Score'] > 60]
# Out:
#         Name        Exam      Subject  Score
# 0      Alisa  Semester 1  Mathematics     62
# 3      Alisa  Semester 1      Science     74
# 5   Cathrine  Semester 1      Science     77
# 6      Alisa  Semester 2  Mathematics     85
# 7      Bobby  Semester 2  Mathematics     63
# 9      Alisa  Semester 2      Science     67
# 10     Bobby  Semester 2      Science     89
# 11  Cathrine  Semester 2      Science     81

# %%
df['new_val'] = 5

# %%
df
# Out:
#         Name        Exam      Subject  Score  new_val
# 0      Alisa  Semester 1  Mathematics     62        5
# 1      Bobby  Semester 1  Mathematics     47        5
# 2   Cathrine  Semester 1  Mathematics     55        5
# 3      Alisa  Semester 1      Science     74        5
# 4      Bobby  Semester 1      Science     31        5
# 5   Cathrine  Semester 1      Science     77        5
# 6      Alisa  Semester 2  Mathematics     85        5
# 7      Bobby  Semester 2  Mathematics     63        5
# 8   Cathrine  Semester 2  Mathematics     42        5
# 9      Alisa  Semester 2      Science     67        5
# 10     Bobby  Semester 2      Science     89        5
# 11  Cathrine  Semester 2      Science     81        5

# %%
df['Passed'] = df['Score'] > 60
df
# Out:
#         Name        Exam      Subject  Score  new_val  Passed
# 0      Alisa  Semester 1  Mathematics     62        5    True
# 1      Bobby  Semester 1  Mathematics     47        5   False
# 2   Cathrine  Semester 1  Mathematics     55        5   False
# 3      Alisa  Semester 1      Science     74        5    True
# 4      Bobby  Semester 1      Science     31        5   False
# 5   Cathrine  Semester 1      Science     77        5    True
# 6      Alisa  Semester 2  Mathematics     85        5    True
# 7      Bobby  Semester 2  Mathematics     63        5    True
# 8   Cathrine  Semester 2  Mathematics     42        5   False
# 9      Alisa  Semester 2      Science     67        5    True
# 10     Bobby  Semester 2      Science     89        5    True
# 11  Cathrine  Semester 2      Science     81        5    True

# %%
def get_semester(exam_name):
    return int(exam_name.split()[1])

# %%
df['Semester'] = df['Exam'].apply(get_semester)

# %%
df[['Exam', 'Semester']]
# Out:
#           Exam  Semester
# 0   Semester 1         1
# 1   Semester 1         1
# 2   Semester 1         1
# 3   Semester 1         1
# 4   Semester 1         1
# 5   Semester 1         1
# 6   Semester 2         2
# 7   Semester 2         2
# 8   Semester 2         2
# 9   Semester 2         2
# 10  Semester 2         2
# 11  Semester 2         2

# %%
df.groupby('Name')['Score']

# %%
df.groupby('Name')['Score'].mean()
# Out:
# Name
# Alisa       72.00
# Bobby       57.50
# Cathrine    63.75
# Name: Score, dtype: float64

# %%
df.groupby('Name').agg({'Score': ['sum', 'mean']})
# Out:
#          Score
#            sum   mean
# Name
# Alisa      288  72.00
# Bobby      230  57.50
# Cathrine   255  63.75

# %%
df.plot(kind='bar', x='Name', y='Score')

# %%
df.plot.bar(x='Name', y='Score')
